# %%
import numpy as np
import matplotlib.pyplot as plt

def dy(y, x):
    return 2   

dx = 0.5 #steglengde

# Startverdier
y = -15
x = -5

while x <= 5:
    y = y + dy(y, x)*dx
    x = x + dx
    plt.plot(x, y, '.')
    
    
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def dy(y, x):
    return y   

dx = 0.1 #steglengde

# Startverdier
y = 1
x = 0

while x <= 4:
    y = y + dy(y, x)*dx
    x = x + dx
    plt.plot(x, y, '.')
    
    
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def dy(y, x):
    return 0.05*y   

dx = 0.2 #steglengde

# Startverdier
y = 2_000_000
x = 0

while x <= 20:
    y = y + dy(y, x)*dx
    x = x + dx
    plt.plot(x, y, '.')
    
    
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def dy(y, x):
    return 244*np.exp(0.05*x)   

dx = 0.1 #steglengde

# Startverdier
y = 5000
x = 0

while x <= 10:
    y = y + dy(y, x)*dx
    x = x + dx
    plt.plot(x, y, '.')
    
    
plt.show()

# %%
import matplotlib.pyplot as plt

def dy(y, x):
    return 9.81

y = 0 
x = 0
dx = 0.1

while x <= 2:
    y = y + dy(y, x)*dx
    x = x + dx
    
    plt.plot(x, y, '.')

# %%
import matplotlib.pyplot as plt

def dy(y, x):
    return 2

y = 1 
x = 0
dx = 0.1

while x <= 5:
    y = y + dy(y, x)*dx
    x = x + dx
    
    plt.plot(x, y, '.')

# %%
import matplotlib.pyplot as plt

def dy(y, x):
    return 0.45*y

y = 1 
x = 0
dx = 0.1

while x <= 10:
    y = y + dy(y, x)*dx
    x = x + dx
    
    plt.plot(x, y, '.')

# %%
import matplotlib.pyplot as plt

def dy(y, x):
    return 0.3*y

y = 10_000 
x = 0
dx = 0.1

while x <= 25:
    y = y + dy(y, x)*dx
    x = x + dx
    
    plt.plot(x, y, '.')

# %%
import matplotlib.pyplot as plt

def dy(y, x):
    return -0.11*y

y = 200_000 
x = 0
dx = 0.1

while x <= 20:
    y = y + dy(y, x)*dx
    x = x + dx
    
    plt.plot(x, y, '.')

# %%
import matplotlib.pyplot as plt
from math import exp, log

#logistisk k=0.11
def dy(y, x):
    return 0.22*y*(1-y/100)

y = 10 
x = 0
dx = 0.05

yverdier = []
xverdier = []

while x <= 30:
    xverdier.append(x)
    yverdier.append(y)

    y = y + dy(y, x)*dx
    x = x + dx
    
    #plt.plot(x, y, '.')
    
plt.plot(xverdier, yverdier)

# %%
a = 0
b = 5
n = 10

def f(x):
    return 0.5*x + 2

bredde = (b - a)/n
areal = 0

for i in range(n):
    hoyde = f(a + i*bredde)
    areal = areal + høyde*bredde

print(areal)

# %%
int("2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 int("2.1")
#
# ValueError: invalid literal for int() with base 10: '2.1'

# %%
int("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 int("")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
while True:
  try:
        svar = int(input("\nSvar: "))
        if not 1 <= svar <= 3:
            raise ValueError()
        break
       
  except ValueError:
        print("Skrive inn et heltall mellom 1 og 3.\n")
# Out:
# Svar:  4
# Skrive inn et heltall.

# %%
import numpy as np
import matplotlib.pyplot as plt

def dy(y, x):
    return (7-1)/(1-(-2))  

dx = 0.1 #steglengde

# Startverdier
y = 1
x = -2

while x <= 1:
    y = y + dy(y, x)*dx
    x = x + dx
    plt.plot(x, y, '.')    
    
plt.show()
